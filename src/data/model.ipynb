# %% [markdown]
# # Fetch Results From MongoDB

# %%
import os
from pymongo import MongoClient
from dotenv import load_dotenv
import pandas as pd

load_dotenv('/Users/aymanhaque/Developer/Enterprise/Shelves/.env.local')


MONGO_URI = os.getenv("MONGODB_URI")
client = MongoClient(MONGO_URI)

db = client['lib']  
books_collection = db['books']
book_data_cursor = books_collection.find()

book_data_list = [{key: str(value) for key, value in book.items()} for book in book_data_cursor]
books_df = pd.DataFrame(book_data_list)

print(books_df.head(10))
# Out:
#                         _id                              title  \
# 0  670c5f6c5d5129e0921e7206                It Ends At Midnight
# 1  670c5f6c5d5129e0921e7207                Sailor Moon, Vol. 1
# 2  670c5f6c5d5129e0921e7208            The John Lennon Letters
# 3  670c5f6c5d5129e0921e7209                      The Awakening
# 4  670c5f6c5d5129e0921e720a                    A Força do Amor
# 5  670c5f6c5d5129e0921e720b                        Above Water
# 6  670c5f6c5d5129e0921e720c  Lenny Marks Gets Away With Murder
# 7  670c5f6c5d5129e0921e720d                           Tease Me
# 8  670c5f6c5d5129e0921e720e              The Kiss & The Killer
# 9  670c5f6c5d5129e0921e720f                      Choosing Theo
#
#              author               length  \
# 0      Harriet Tyce            320 pages
# 1    Naoko Takeuchi            200 pages
# 2       John Lennon            400 pages
# 3       Kate Chopin            208 pages
# 4       Angela Hart            240 pages
# 5     Trish Kearney            264 pages
# 6      Kerryn Mayne            341 pages
# 7    Miranda Forbes            200 pages
# 8      Melissa Marr  6 hours, 11 minutes
# 9  Victoria Aveline            369 pages
#
#                                                genre  \
# 0  ['fiction', 'thriller', 'dark', 'mysterious', ...
# 1  ['fiction', 'fantasy', 'manga', 'adventurous',...
# 2  ['nonfiction', 'biography', 'music', 'informat...
# 3  ['fiction', 'classics', 'reflective', 'slow-pa...
# 4  ['fiction', 'autobiography', 'childrens', 'lit...
# 5  ['nonfiction', 'memoir', 'emotional', 'reflect...
# 6  ['fiction', 'contemporary', 'mystery', 'emotio...
# 7  ['fiction', 'erotica', 'lighthearted', 'myster...
# 8  ['fiction', 'fantasy', 'romance', 'adventurous...
# 9  ['fiction', 'romance', 'science fiction', 'adv...
#
#                                          description  \
# 0  THREE FRIENDS. TWO BODIES. AND A PARTY TO DIE ...
# 1  When Usagi Tsukino adopts a stray cat, she get...
# 2  A lifetime of letters, collected for the first...
# 3  'The voice of the sea is seductive; never ceas...
# 4  Uma menina muito magoada e a mãe adotiva que n...
# 5  At age thirteen, Trish Kearney’s idyllic child...
# 6  Kerryn Mayne’s stunning debut is an irresistib...
# 7  Whatever your pleasure you'll love what you di...
# 8  The next installment in a new faery and fanged...
# 9  Being kidnapped by aliens is only the start of...
#
#                                           reviewData          publishDate  \
# 0  {'theme': {'adventurous': 5, 'challenging': 11...  2022-04-14 04:00:00
# 1  {'theme': {'adventurous': 81, 'challenging': 0...  2003-01-01 05:00:00
# 2  {'theme': {'adventurous': 0, 'challenging': 0,...  2013-10-29 04:00:00
# 3  {'theme': {'adventurous': 5, 'challenging': 23...  2018-02-07 05:00:00
# 4  {'theme': {'adventurous': 0, 'challenging': 0,...  2019-05-08 04:00:00
# 5  {'theme': {'adventurous': 0, 'challenging': 66...  2021-05-15 04:00:00
# 6  {'theme': {'adventurous': 8, 'challenging': 19...  2023-02-21 05:00:00
# 7  {'theme': {'adventurous': 0, 'challenging': 0,...  2008-04-07 04:00:00
# 8  {'theme': {'adventurous': 100, 'challenging': ...  2021-07-20 04:00:00
# 9  {'theme': {'adventurous': 73, 'challenging': 6...  2020-03-04 05:00:00
#
#                                               imgUrl           isbn  \
# 0  https://cdn.thestorygraph.com/ooq9pxwmyj6c5etk...  9781472280091
# 1  https://cdn.thestorygraph.com/hn6d874fef1n2u5j...  9781892213013
# 2  https://cdn.thestorygraph.com/omj7x7c7m77brbmw...  9780316200783
# 3  https://cdn.thestorygraph.com/qz439rbfwuqus20p...  9780241341421
# 4  https://cdn.thestorygraph.com/zrczgizrtersmx9b...  9789897544019
# 5  https://cdn.thestorygraph.com/r8oc2nbw2ajct73y...  9781529333640
# 6  https://cdn.thestorygraph.com/v7qi2eeixn7n97dx...  9781761048050
# 7  https://assets.thestorygraph.com/assets/placeh...  9781906125844
# 8  https://cdn.thestorygraph.com/gztdteprro95mbu8...     1662256108
# 9  https://cdn.thestorygraph.com/ljocahvsxlpj2z09...           None
#
#                 publishName     format    language rating  \
# 0                  Wildfire    Digital     English   3.34
# 1                  Tokyopop  Paperback     English   4.24
# 2  Little Brown and Company  Paperback     English   4.16
# 3          Penguin Classics  Paperback     English    3.6
# 4                  Marcador  Paperback  Portuguese      4
# 5    Hachette Books Ireland  Paperback     English   4.56
# 6            Penguin eBooks    Digital     English   4.07
# 7               Xcite Books  Paperback     English   2.25
# 8           OrangeSky Audio      Audio     English   3.66
# 9            Self-Published    Digital     English   4.02
#
#                                                stats  __v
# 0  {'userRead': 10, 'userLiked': 6, 'userRented': 1}  NaN
# 1   {'userRead': 0, 'userLiked': 0, 'userRented': 0}  NaN
# 2   {'userRead': 1, 'userLiked': 1, 'userRented': 4}  NaN
# 3   {'userRead': 5, 'userLiked': 3, 'userRented': 1}  NaN
# 4   {'userRead': 0, 'userLiked': 0, 'userRented': 0}  NaN
# 5   {'userRead': 0, 'userLiked': 0, 'userRented': 0}  NaN
# 6   {'userRead': 0, 'userLiked': 0, 'userRented': 0}  NaN
# 7   {'userRead': 0, 'userLiked': 0, 'userRented': 0}  NaN
# 8   {'userRead': 0, 'userLiked': 0, 'userRented': 0}  NaN
# 9   {'userRead': 0, 'userLiked': 0, 'userRented': 0}  NaN

# %% [markdown]
# # Generate Prompt Completions For OpenAI Fine Tuning

# %% [markdown]
# Training Data With Descriptions

# %%
import json

db = client['lib']
books_collection = db['books'] 

def generate_prompt_completion(book):

    title = book.get('title', 'Unknown Title')
    author = book.get('author', 'Unknown Author')
    genres = ", ".join(book.get('genre', []))  
    pace_data = book.get('reviewData', {}).get('pace', {})
    themes_data = book.get('reviewData', {}).get('theme', {})
    
    genre_str = genres if genres else "any genre"
    pace_str = "fast-paced" if pace_data.get('fast', 0) > 10 else "medium-paced" if pace_data.get('medium', 0) > 10 else "slow-paced"
    theme_str = ", ".join([theme for theme, count in themes_data.items() if count > 10]) if themes_data else "any theme"
    
    prompt = f"I enjoy {theme_str} books that are {pace_str} and fall into {genre_str}."
    
    description = book.get('description', 'No description available.')
    completion = f"{title} by {author}. {description}"
    
    return {
        "prompt": prompt,
        "completion": completion
    }

book_data_cursor = books_collection.find()

prompt_completion_list = []

for book in book_data_cursor:
    prompt_completion = generate_prompt_completion(book)
    prompt_completion_list.append(prompt_completion)

with open("prompt_completion_pairs.jsonl", "w") as jsonl_file:
    for pair in prompt_completion_list:
        jsonl_file.write(json.dumps(pair) + "\n")

print(f"Generated {len(prompt_completion_list)} prompt-completion pairs.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 32
#      28 book_data_cursor = books_collection.find()
#      30 prompt_completion_list = []
# ---> 32 for book in book_data_cursor:
#      33     prompt_completion = generate_prompt_completion(book)
#      34     prompt_completion_list.append(prompt_completion)
#
# File /opt/miniconda3/envs/book-recommender-env/lib/python3.10/site-packages/pymongo/synchronous/cursor.py:1281, in Cursor.__next__(self)
#    1280 def __next__(self) -> _DocumentType:
# -> 1281     return self.next()
#
# File /opt/miniconda3/envs/book-recommender-env/lib/python3.10/site-packages/pymongo/synchronous/cursor.py:1257, in Cursor.next(self)
#    1255 if self._empty:
#    1256     raise StopIteration
# -> 1257 if len(self._data) or self._refresh():
#    1258     return self._data.popleft()
#    1259 else:
#
# File /opt/miniconda3/envs/book-recommender-env/lib/python3.10/site-packages/pymongo/synchronous/cursor.py:1228, in Cursor._refresh(self)
#    1213     # Exhaust cursors don't send getMore messages.
#    1214     g = self._getmore_class(
#    1215         self._dbname,
#    1216         self._collname,
#    (...)
#    1226         self._comment,
#    1227     )
# -> 1228     self._send_message(g)
#    1230 return len(self._data)
#
# File /opt/miniconda3/envs/book-recommender-env/lib/python3.10/site-packages/pymongo/synchronous/cursor.py:1100, in Cursor._send_message(self, operation)
#    1097     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1099 try:
# -> 1100     response = client._run_operation(
#    1101         operation, self._unpack_response, address=self._address
#    1102     )
#    1103 except OperationFailure as exc:
#    1104     if exc.code in _CURSOR_CLOSED_ERRORS or self._exhaust:
#    1105         # Don't send killCursors because the cursor is already closed.
#
# File /opt/miniconda3/envs/book-recommender-env/lib/python3.10/site-packages/pymongo/_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File /opt/miniconda3/envs/book-recommender-env/lib/python3.10/site-packages/pymongo/synchronous/mongo_client.py:1754, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1744     operation.reset()  # Reset op in case of retry.
#    1745     return server.run_operation(
#    1746         conn,
#    1747         operation,
#    (...)
#    1751         self,
#    1752     )
# -> 1754 return self._retryable_read(
#    1755     _cmd,
#    1756     operation.read_preference,
#    1757     operation.session,  # type: ignore[arg-type]
#    1758     address=address,
#    1759     retryable=isinstance(operation, _Query),
#    1760     operation=operation.name,
#    1761 )
#
# File /opt/miniconda3/envs/book-recommender-env/lib/python3.10/site-packages/pymongo/synchronous/mongo_client.py:1863, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    1858 # Ensure that the client supports retrying on reads and there is no session in
#    1859 # transaction, otherwise, we will not support retry behavior for this call.
#    1860 retryable = bool(
#    1861     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    1862 )
# -> 1863 return self._retry_internal(
#    1864     func,
#    1865     session,
#    1866     None,
#    1867     operation,
#    1868     is_read=True,
#    1869     address=address,
#    1870     read_pref=read_pref,
#    1871     retryable=retryable,
#    1872     operation_id=operation_id,
#    1873 )
#
# File /opt/miniconda3/envs/book-recommender-env/lib/python3.10/site-packages/pymongo/_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File /opt/miniconda3/envs/book-recommender-env/lib/python3.10/site-packages/pymongo/synchronous/mongo_client.py:1830, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1793 @_csot.apply
#    1794 def _retry_internal(
#    1795     self,
#    (...)
#    1804     operation_id: Optional[int] = None,
#    1805 ) -> T:
#    1806     """Internal retryable helper for all client transactions.
#    1807
#    1808     :param func: Callback function we want to retry
#    (...)
#    1817     :return: Output of the calling func()
#    1818     """
#    1819     return _ClientConnectionRetryable(
#    1820         mongo_client=self,
#    1821         func=func,
#    1822         bulk=bulk,
#    1823         operation=operation,
#    1824         is_read=is_read,
#    1825         session=session,
#    1826         read_pref=read_pref,
#    1827         address=address,
#    1828         retryable=retryable,
#    1829         operation_id=operation_id,
# -> 1830     ).run()
#
# File /opt/miniconda3/envs/book-recommender-env/lib/python3.10/site-packages/pymongo/synchronous/mongo_client.py:2554, in _ClientConnectionRetryable.run(self)
#    2552 self._check_last_error(check_csot=True)
#    2553 try:
# -> 2554     return self._read() if self._is_read else self._write()
#    2555 except ServerSelectionTimeoutError:
#    2556     # The application may think the write was never attempted
#    2557     # if we raise ServerSelectionTimeoutError on the retry
#    2558     # attempt. Raise the original exception instead.
#    2559     self._check_last_error()
#
# File /opt/miniconda3/envs/book-recommender-env/lib/python3.10/site-packages/pymongo/synchronous/mongo_client.py:2697, in _ClientConnectionRetryable._read(self)
#    2695 if self._retrying and not self._retryable:
#    2696     self._check_last_error()
# -> 2697 return self._func(self._session, self._server, conn, read_pref)
#
# File /opt/miniconda3/envs/book-recommender-env/lib/python3.10/site-packages/pymongo/synchronous/mongo_client.py:1745, in MongoClient._run_operation.<locals>._cmd(_session, server, conn, read_preference)
#    1738 def _cmd(
#    1739     _session: Optional[ClientSession],
#    1740     server: Server,
#    1741     conn: Connection,
#    1742     read_preference: _ServerMode,
#    1743 ) -> Response:
#    1744     operation.reset()  # Reset op in case of retry.
# -> 1745     return server.run_operation(
#    1746         conn,
#    1747         operation,
#    1748         read_preference,
#    1749         self._event_listeners,
#    1750         unpack_res,
#    1751         self,
#    1752     )
#
# File /opt/miniconda3/envs/book-recommender-env/lib/python3.10/site-packages/pymongo/synchronous/helpers.py:45, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      42 from pymongo.synchronous.pool import Connection
#      44 try:
# ---> 45     return func(*args, **kwargs)
#      46 except OperationFailure as exc:
#      47     if no_reauth:
#
# File /opt/miniconda3/envs/book-recommender-env/lib/python3.10/site-packages/pymongo/synchronous/server.py:208, in Server.run_operation(self, conn, operation, read_preference, listeners, unpack_res, client)
#     206 else:
#     207     conn.send_message(data, max_doc_size)
# --> 208     reply = conn.receive_message(request_id)
#     210 # Unpack and check for command errors.
#     211 if use_cmd:
#
# File /opt/miniconda3/envs/book-recommender-env/lib/python3.10/site-packages/pymongo/synchronous/pool.py:592, in Connection.receive_message(self, request_id)
#     590     return receive_message(self, request_id, self.max_message_size)
#     591 except BaseException as error:
# --> 592     self._raise_connection_failure(error)
#
# File /opt/miniconda3/envs/book-recommender-env/lib/python3.10/site-packages/pymongo/synchronous/pool.py:590, in Connection.receive_message(self, request_id)
#     585 """Receive a raw BSON message or raise ConnectionFailure.
#     586
#     587 If any exception is raised, the socket is closed.
#     588 """
#     589 try:
# --> 590     return receive_message(self, request_id, self.max_message_size)
#     591 except BaseException as error:
#     592     self._raise_connection_failure(error)
#
# File /opt/miniconda3/envs/book-recommender-env/lib/python3.10/site-packages/pymongo/synchronous/network.py:340, in receive_message(conn, request_id, max_message_size)
#     338     data = decompress(_receive_data_on_socket(conn, length - 25, deadline), compressor_id)
#     339 else:
# --> 340     data = _receive_data_on_socket(conn, length - 16, deadline)
#     342 try:
#     343     unpack_reply = _UNPACK_REPLY[op_code]
#
# File /opt/miniconda3/envs/book-recommender-env/lib/python3.10/site-packages/pymongo/synchronous/network.py:396, in _receive_data_on_socket(conn, length, deadline)
#     394     if _csot.get_timeout() and deadline is not None:
#     395         conn.set_conn_timeout(max(deadline - time.monotonic(), 0))
# --> 396     chunk_length = conn.conn.recv_into(mv[bytes_read:])
#     397 except BLOCKING_IO_ERRORS:
#     398     raise socket.timeout("timed out") from None
#
# File /opt/miniconda3/envs/book-recommender-env/lib/python3.10/ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/miniconda3/envs/book-recommender-env/lib/python3.10/ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# Training Data And Validation Data Generator

# %%
import json
import random
import os

db = client['lib']
books_collection = db['books'] 

def generate_messages(book):
    title = book.get('title', 'Unknown Title')
    author = book.get('author', 'Unknown Author')
    genres = ", ".join(book.get('genre', []))
    pace_data = book.get('reviewData', {}).get('pace', {})
    themes_data = book.get('reviewData', {}).get('theme', {})
    
    genre_str = genres if genres else "any genre"
    pace_str = "fast-paced" if pace_data.get('fast', 0) > 10 else "medium-paced" if pace_data.get('medium', 0) > 10 else "slow-paced"
    theme_str = ", ".join([theme for theme, count in themes_data.items() if count > 10]) if themes_data else "any theme"
    
    user_content = f"I enjoy {theme_str} books that are {pace_str} and fall into {genre_str}."
    
    assistant_content = f"{title} by {author}."
    
    return {
        "messages": [
            {"role": "user", "content": user_content},
            {"role": "assistant", "content": assistant_content}
        ]
    }

book_data_cursor = books_collection.find()

message_list = []

for book in book_data_cursor:
    messages = generate_messages(book)
    message_list.append(messages)

random.shuffle(message_list)

split_index = int(0.8 * len(message_list))
training_data = message_list[:split_index]
validation_data = message_list[split_index:]

output_folder = "src/data/trained_data"  

os.makedirs(output_folder, exist_ok=True)

training_file_path = os.path.join(output_folder, "training_data_no_desc.jsonl")
with open(training_file_path, "w") as training_file:
    for pair in training_data:
        training_file.write(json.dumps(pair) + "\n")

validation_file_path = os.path.join(output_folder, "validation_data_no_desc.jsonl")
with open(validation_file_path, "w") as validation_file:
    for pair in validation_data:
        validation_file.write(json.dumps(pair) + "\n")

print(f"Training data saved to {training_file_path}")
print(f"Validation data saved to {validation_file_path}")

# %% [markdown]
# # Importing Model From HuggingFace

# %% [markdown]
# ## SBERT Model
# - load data from mongo into a pd data frame
# - parse book data
# - load sbert model and create text embeddings
# - write user query
# - calc cos sim to find similar books

# %%
from pymongo import MongoClient
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

MONGO_URI = os.getenv("MONGODB_URI")
client = MongoClient(MONGO_URI)

db = client['lib']  
books_collection = db['books']
book_data_cursor = books_collection.find()

# Convert MongoDB cursor to DataFrame for easy manipulation
book_data_list = [{key: str(value) for key, value in book.items()} for book in book_data_cursor]
books_df = pd.DataFrame(book_data_list)

# Display a sample of the data
print(books_df.head(10))
# Out:
#                         _id                              title  \
# 0  670c5f6c5d5129e0921e7206                It Ends At Midnight
# 1  670c5f6c5d5129e0921e7207                Sailor Moon, Vol. 1
# 2  670c5f6c5d5129e0921e7208            The John Lennon Letters
# 3  670c5f6c5d5129e0921e7209                      The Awakening
# 4  670c5f6c5d5129e0921e720a                    A Força do Amor
# 5  670c5f6c5d5129e0921e720b                        Above Water
# 6  670c5f6c5d5129e0921e720c  Lenny Marks Gets Away With Murder
# 7  670c5f6c5d5129e0921e720d                           Tease Me
# 8  670c5f6c5d5129e0921e720e              The Kiss & The Killer
# 9  670c5f6c5d5129e0921e720f                      Choosing Theo
#
#              author               length  \
# 0      Harriet Tyce            320 pages
# 1    Naoko Takeuchi            200 pages
# 2       John Lennon            400 pages
# 3       Kate Chopin            208 pages
# 4       Angela Hart            240 pages
# 5     Trish Kearney            264 pages
# 6      Kerryn Mayne            341 pages
# 7    Miranda Forbes            200 pages
# 8      Melissa Marr  6 hours, 11 minutes
# 9  Victoria Aveline            369 pages
#
#                                                genre  \
# 0  ['fiction', 'thriller', 'dark', 'mysterious', ...
# 1  ['fiction', 'fantasy', 'manga', 'adventurous',...
# 2  ['nonfiction', 'biography', 'music', 'informat...
# 3  ['fiction', 'classics', 'reflective', 'slow-pa...
# 4  ['fiction', 'autobiography', 'childrens', 'lit...
# 5  ['nonfiction', 'memoir', 'emotional', 'reflect...
# 6  ['fiction', 'contemporary', 'mystery', 'emotio...
# 7  ['fiction', 'erotica', 'lighthearted', 'myster...
# 8  ['fiction', 'fantasy', 'romance', 'adventurous...
# 9  ['fiction', 'romance', 'science fiction', 'adv...
#
#                                          description  \
# 0  THREE FRIENDS. TWO BODIES. AND A PARTY TO DIE ...
# 1  When Usagi Tsukino adopts a stray cat, she get...
# 2  A lifetime of letters, collected for the first...
# 3  'The voice of the sea is seductive; never ceas...
# 4  Uma menina muito magoada e a mãe adotiva que n...
# 5  At age thirteen, Trish Kearney’s idyllic child...
# 6  Kerryn Mayne’s stunning debut is an irresistib...
# 7  Whatever your pleasure you'll love what you di...
# 8  The next installment in a new faery and fanged...
# 9  Being kidnapped by aliens is only the start of...
#
#                                           reviewData          publishDate  \
# 0  {'theme': {'adventurous': 5, 'challenging': 11...  2022-04-14 04:00:00
# 1  {'theme': {'adventurous': 81, 'challenging': 0...  2003-01-01 05:00:00
# 2  {'theme': {'adventurous': 0, 'challenging': 0,...  2013-10-29 04:00:00
# 3  {'theme': {'adventurous': 5, 'challenging': 23...  2018-02-07 05:00:00
# 4  {'theme': {'adventurous': 0, 'challenging': 0,...  2019-05-08 04:00:00
# 5  {'theme': {'adventurous': 0, 'challenging': 66...  2021-05-15 04:00:00
# 6  {'theme': {'adventurous': 8, 'challenging': 19...  2023-02-21 05:00:00
# 7  {'theme': {'adventurous': 0, 'challenging': 0,...  2008-04-07 04:00:00
# 8  {'theme': {'adventurous': 100, 'challenging': ...  2021-07-20 04:00:00
# 9  {'theme': {'adventurous': 73, 'challenging': 6...  2020-03-04 05:00:00
#
#                                               imgUrl           isbn  \
# 0  https://cdn.thestorygraph.com/ooq9pxwmyj6c5etk...  9781472280091
# 1  https://cdn.thestorygraph.com/hn6d874fef1n2u5j...  9781892213013
# 2  https://cdn.thestorygraph.com/omj7x7c7m77brbmw...  9780316200783
# 3  https://cdn.thestorygraph.com/qz439rbfwuqus20p...  9780241341421
# 4  https://cdn.thestorygraph.com/zrczgizrtersmx9b...  9789897544019
# 5  https://cdn.thestorygraph.com/r8oc2nbw2ajct73y...  9781529333640
# 6  https://cdn.thestorygraph.com/v7qi2eeixn7n97dx...  9781761048050
# 7  https://assets.thestorygraph.com/assets/placeh...  9781906125844
# 8  https://cdn.thestorygraph.com/gztdteprro95mbu8...     1662256108
# 9  https://cdn.thestorygraph.com/ljocahvsxlpj2z09...           None
#
#                 publishName     format    language rating  \
# 0                  Wildfire    Digital     English   3.34
# 1                  Tokyopop  Paperback     English   4.24
# 2  Little Brown and Company  Paperback     English   4.16
# 3          Penguin Classics  Paperback     English    3.6
# 4                  Marcador  Paperback  Portuguese      4
# 5    Hachette Books Ireland  Paperback     English   4.56
# 6            Penguin eBooks    Digital     English   4.07
# 7               Xcite Books  Paperback     English   2.25
# 8           OrangeSky Audio      Audio     English   3.66
# 9            Self-Published    Digital     English   4.02
#
#                                                stats  __v
# 0  {'userRead': 10, 'userLiked': 6, 'userRented': 1}  NaN
# 1   {'userRead': 0, 'userLiked': 0, 'userRented': 0}  NaN
# 2   {'userRead': 1, 'userLiked': 1, 'userRented': 4}  NaN
# 3   {'userRead': 5, 'userLiked': 3, 'userRented': 1}  NaN
# 4   {'userRead': 0, 'userLiked': 0, 'userRented': 0}  NaN
# 5   {'userRead': 0, 'userLiked': 0, 'userRented': 0}  NaN
# 6   {'userRead': 0, 'userLiked': 0, 'userRented': 0}  NaN
# 7   {'userRead': 0, 'userLiked': 0, 'userRented': 0}  NaN
# 8   {'userRead': 0, 'userLiked': 0, 'userRented': 0}  NaN
# 9   {'userRead': 0, 'userLiked': 0, 'userRented': 0}  NaN

# %%
import json

# Function to parse and format book data
def create_book_text(book):
    genres = ", ".join(book.get('genre', []))

    # Parse reviewData to ensure it's a dictionary
    try:
        review_data = json.loads(book.get('reviewData', '{}').replace("'", "\""))
        themes_data = review_data.get('theme', {})
        pace_data = review_data.get('pace', {})
    except (json.JSONDecodeError, AttributeError):
        themes_data = {}
        pace_data = {}

    theme_str = ", ".join([theme for theme, count in themes_data.items() if int(count) > 10]) if themes_data else "any theme"
    pace_str = "fast-paced" if int(pace_data.get('fast', 0)) > 10 else "medium-paced" if int(pace_data.get('medium', 0)) > 10 else "slow-paced"
    
    return f"{book['title']} by {book['author']}. Genre: {genres}. Themes: {theme_str}. Pace: {pace_str}. Description: {book['description']}."

# Apply formatting to each book in the DataFrame
books_df['text'] = books_df.apply(create_book_text, axis=1)

# %%
from tqdm import tqdm
import numpy as np
from sentence_transformers import SentenceTransformer

# Load the SBERT model
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# Initialize an empty list to store embeddings
book_embeddings = []

# Loop through each book text with a progress bar
for text in tqdm(books_df['text'].tolist(), desc="Generating Embeddings"):
    embedding = model.encode(text)
    book_embeddings.append(embedding)

# Convert list to an array
book_embeddings = np.array(book_embeddings)
# Out:
# Generating Embeddings: 100%|██████████| 109023/109023 [15:57<00:00, 113.83it/s]

# %%
# Example user input
likes = "harry potter"
dislikes = "Sorcerer's Stone"

# Generate embeddings for likes and dislikes
like_embedding = model.encode([likes])
dislike_embedding = model.encode([dislikes])

from sklearn.metrics.pairwise import cosine_similarity

# Calculate similarity of each book to the "likes" embedding
positive_similarities = cosine_similarity(like_embedding, book_embeddings).flatten()

# Calculate similarity of each book to the "dislikes" embedding
negative_similarities = cosine_similarity(dislike_embedding, book_embeddings).flatten()

# Adjust scores: subtract similarity to disliked books from similarity to liked books
final_scores = positive_similarities - (0.5 * negative_similarities)  # Adjust the weight (0.5) based on preference

# %%
# Get indices of the top 5 recommendations
top_indices = final_scores.argsort()[::-1][:5]

# Display the recommendations with scores
print("Top Book Recommendations:")
for idx in top_indices:
    title = books_df.iloc[idx]['title']
    author = books_df.iloc[idx]['author']
    score = final_scores[idx]
    print(f"Title: {title}, Author: {author}, Score: {score:.4f}")
# Out:
# Top Book Recommendations:
# Title: Harry Potter and the Chamber of Secrets (Enhanced Edition), Author: J.K. Rowling, Score: 0.3959
# Title: Harry Potter y la Piedra Filosofal, Author: J.K. Rowling, Score: 0.3925
# Title: Harry Potter and the Chamber of Secrets, Author: J.K. Rowling, Score: 0.3917
# Title: Harry Potter and the Chamber of Secrets, Author: J.K. Rowling, Score: 0.3917
# Title: Harry Potter and the Order of the Phoenix, Author: J.K. Rowling, Score: 0.3846
